# %%
import sys
import numpy as np
import math
from copy import deepcopy
from treelib import Node, Tree
import itertools
import TaAgent
import StudentAgent
import time

"""
EMPTY = 0
BLACK_MAN = 1
BLACK_KING = 2
WHITE_MAN = 3
WHITE_KING = 4
"""

class Board(object):
    def __init__(self, board=None):
        if board is not None:
            self.board = board
        else:
            self.board = np.zeros((8, 8), dtype=np.int32)
            self.board[1:3, :] = 1 # set all black men
            self.board[5:7, :] = 3 # set all white men
        self.white_piece_symbol = "X"
        self.black_piece_symbol = "Y"
        self.white_pieces = [3, 4]
        self.black_pieces = [1, 2]
        self.white_man = 3
        self.white_king = 4
        self.black_man = 1
        self.black_king = 2
        self.n_turns = 0  
    
    def loc(self, pos):
        if not self.is_outside_board(pos):
            return self.board[pos[0], pos[1]]
        else:
            raise IndexError("Position outside of board")

    def player_owns_piece(self, player, pos):
        if not self.is_outside_board(pos):
            if self.board[pos[0], pos[1]] in self.white_pieces and player == "White":
                return True
            elif self.board[pos[0], pos[1]] in self.black_pieces and player == "Black":
                return True
            else:
                return False
        else:
            raise IndexError("Position outside of board")
    
    def is_outside_board(self, pos):
        if pos[0] in list(range(8)) and pos[1] in list(range(8)):
            return False
        else:
            return True
    
    def visualize_board(self):
        str_board = self.board.tolist()
        for board_row in str_board:
            board_row = [str(num) for num in board_row]
            print(" ".join(board_row))

    def is_promoted(self, pos: tuple):
        if ((self.board[pos[0], pos[1]] == 2) or 
            (self.board[pos[0], pos[1]] == 4)):
            return True
        else:
            return False

    def check_king_promotion(self):
        white_king_row = self.board[0, :]
        white_king_row[white_king_row == 3] = 4
        black_king_row = self.board[7, :]
        black_king_row[black_king_row == 1] = 2
        self.board[0, :] = white_king_row[:]
        self.board[7, :] = black_king_row[:]

    def measure(self, player):
        if player == "Black":
            myPieces = np.count_nonzero(self.board == 1)
            myPromoted = np.count_nonzero(self.board == 2)
            opponentPieces = np.count_nonzero(self.board == 3)
            opponentPromoted = np.count_nonzero(self.board == 4)
        else:
            myPieces = np.count_nonzero(self.board == 3)
            myPromoted = np.count_nonzero(self.board == 4)
            opponentPieces = np.count_nonzero(self.board == 1)
            opponentPromoted = np.count_nonzero(self.board == 2)

        return {
            'myPieces' : myPieces,
            'myPromoted' : myPromoted,
            'opponentPieces' : opponentPieces,
            'opponentPromoted' : opponentPromoted
        }

    def check_win(self, player, moves):
        metric = self.measure(player)
        if (
            # No moves left
            len(moves) == 0 or
            (
            # One man versus One King
            metric['myPieces'] == 1
            and metric['myPromoted'] == 0
            and metric['opponentPieces'] == 0
            and metric['opponentPromoted'] == 1
            )
        ):
            return True 
    
    def remove_piece(self, pos):
        self.board[pos[0], pos[1]] = 0
      
    def move_piece(self, start_pos, end_pos):
        piece = self.loc(start_pos)
        self.remove_piece(start_pos)
        self.board[end_pos[0], end_pos[1]] = piece

    def opponents_between_two_positions(self, player, p1, p2):
        if p1[0] == p2[0]:
            x1 = p1[0]
            y1 = min(p1[1], p2[1])
            y2 = max(p1[1], p2[1])
            res = self.board[x1, :][y1:y2+1]
        elif p1[1] == p2[1]:
            y1 = p2[1]
            x1 = min(p1[0], p2[0])
            x2 = max(p1[0], p2[0])
            res = self.board[:, y1][x1:x2+1]

        count = 0
        for i in res:
            if player == "White":
                if i == 1 or i == 2:
                    count = count + 1
            elif player == "Black":
                if i == 3 or i == 4:
                    count = count + 1
        
        return count

    def increment_turn(self):
        self.n_turns += 1
    
    

class Student_Move_Checker(object):
    def __init__(self, side, board=None):
        self.board = Board(board=board)
        self.side = side
    
    def get_valid_directions(self, start_pos, end_pos, promoted):
        valid_directions = np.array([[1, 0], [-1, 0], [0, -1], [0, 1]])

        if promoted:
            return valid_directions
        else:
            if start_pos is not None:
                last_direction = self.get_last_direction(start_pos, end_pos)            
                idx = np.where((valid_directions == last_direction).all(axis=1))
                valid_directions = np.delete(valid_directions, idx, axis=0)

            if self.side == "White":
                backwards = np.array([1, 0])
            elif self.side == "Black":
                backwards = np.array([-1, 0])

            idx = np.where((valid_directions == backwards).all(axis=1))
            valid_directions = np.delete(valid_directions, idx, axis=0)
            
            return valid_directions
    
    def get_last_direction(self, start_pos, end_pos):
        direction = start_pos - end_pos
        
        for i, element in enumerate(direction):
            if element > 0:
                direction[i] = 1
            elif element < 0:
                direction[i] = -1

        return direction

    def check_for_promotions(self, temp_gameboard=None):
        if temp_gameboard is None:
            gameboard = self.board
        else:
            gameboard = temp_gameboard

        for i in [0, 7]:
            for j in range(8):
                pos = (i, j)
                if i == 7:
                    if gameboard.loc(pos) == 1:
                        gameboard.board[i][j] = 2
                elif i == 0:
                    if gameboard.loc(pos) == 3:
                        gameboard.board[i][j] = 4
        
    def get_all_legal_moves(self, temp_gameboard=None):

        if temp_gameboard is None:
            gameboard = self.board
        else:
            gameboard = Board(board=np.copy(temp_gameboard.board))

        all_move_list = []
        all_remove_list = []
        all_count_list = []

        for pos in itertools.product(list(range(8)), repeat=2):
            if gameboard.player_owns_piece(self.side, pos):
                # time1 = time.time()
                all_possible_move_tree = self.get_piece_legal_move(self.side, pos, current_gameboard=gameboard)
                # time2 = time.time()

                if all_possible_move_tree.depth() > 0:
                    b = self.listFromTree(all_possible_move_tree)

                    all_move_list.extend(b['move'])
                    all_remove_list.extend(b['remove'])
                    all_count_list.extend(b['count'])

        if len(all_count_list) > 0:
            max_indices = np.argwhere(all_count_list == np.amax(all_count_list)).flatten().tolist()

            valid_moves = [all_move_list[i] for i in max_indices]
            valid_removes = [all_remove_list[i] for i in max_indices]
            valid_counts = [all_count_list[i] for i in max_indices]

            return {
                'move' : valid_moves,
                'remove' : valid_removes,
                'count' : valid_counts
            }
        else:
            return {
                'move' : [],
                'remove' : [],
                'count' : []
            }


    def get_piece_legal_move(
        self, player, position, startPosition=None, current_gameboard=None, lastRemoved=None,
        movetree=None, lastNode=None, canMove=True, hasJumped = False
    ):

        '''
        position is the current position of the piece whose moves we are inspecting
        startPosition is the original position of that move, before any jumps have been made
        '''
        # Initialize empty lists
        if current_gameboard is None:
            current_gameboard = self.board

        # Check for promotions
        self.check_for_promotions(current_gameboard)

        # Add the node to the movetree, or create one if it doesn't exist
        if movetree is None:
            movetree = Tree()

        if current_gameboard.player_owns_piece(self.side, position):
            
            # Create a node for the tree from the current state of the game
            state = TaAgent.State(position, lastRemoved)
            node = Node(tag=state.tag, data=state)

            # if current_gameboard.player_owns_piece(player, position):
            if lastNode is None:
                # Set current node as the root
                movetree.add_node(node)
                lastNode = node
            else:
                # Create a new node as the child of the last node
                movetree.add_node(node, parent=lastNode)
            
            valid_directions = self.get_valid_directions(
                startPosition, position, current_gameboard.is_promoted(position)
            )

            if current_gameboard.is_promoted(position):
                lookup_range = 8
            else:
                lookup_range = 3

            for direction in valid_directions:
                
                jumpIsAvailable = False
                jumpablePiece = None

                for multiplier in range(1, lookup_range):

                    if not current_gameboard.is_promoted(position):
                        if multiplier == 2 or hasJumped:
                            canMove = False
                        elif multiplier == 1 and not hasJumped:
                            canMove = True
                    
                    next = position + multiplier * direction
                    next_next = position + (multiplier + 1) * direction

                    # Check for any collision or invalid moves

                    # Out of board
                    # Quit
                    if current_gameboard.is_outside_board(next):
                        break

                    # You own the next piece
                    # Quit
                    elif current_gameboard.player_owns_piece(self.side, next):
                        break
                    
                    # Collion with two back to back pieces
                    # Quit
                    elif (
                        not current_gameboard.loc(next) == 0
                        and not current_gameboard.is_outside_board(next_next)
                        and not current_gameboard.loc(next_next) == 0
                        and not current_gameboard.player_owns_piece(self.side, next)
                        and not current_gameboard.player_owns_piece(self.side, next_next)
                    ):
                        break
                    
                    if current_gameboard.loc(next) == 0:
                        if jumpIsAvailable:
                            if current_gameboard.opponents_between_two_positions(self.side, position, next) < 2:
                                temp_gameboard = Board(board=np.copy(current_gameboard.board))
                                temp_gameboard.move_piece(position, next)
                                temp_gameboard.remove_piece(jumpablePiece)

                                self.get_piece_legal_move(
                                    self.side, next, startPosition = position,
                                    current_gameboard = temp_gameboard, lastRemoved=jumpablePiece,
                                    movetree = movetree, lastNode = node, canMove = False, hasJumped = True
                                )

                        elif canMove:
                            # gameboard gameboard gameboard
                            temp_gameboard = Board(board=np.copy(current_gameboard.board))
                            temp_gameboard.move_piece(position, next)

                            new_state = TaAgent.State(next, None)
                            new_node = Node(tag=new_state.tag, data=new_state)

                            movetree.add_node(new_node, parent=node)
                    elif (
                        not current_gameboard.loc(next) == 0
                        and not current_gameboard.player_owns_piece(self.side, next)
                    ):
                        if not jumpIsAvailable:
                            jumpIsAvailable = True
                            jumpablePiece = next

        return movetree

    def check_next_move(self, board, start_pos, end_pos):
        self.board = board
        candidate_moves = self.get_all_legal_moves()
        possible_pos_list = self.possible_pos(candidate_moves)
        for choice_idx, start_end_pos in enumerate(possible_pos_list):
            if (start_end_pos[0][0] == start_pos[0] 
                and start_end_pos[0][1] == start_pos[1] 
                and start_end_pos[1][0] == end_pos[0] 
                and start_end_pos[1][1] == end_pos[1]):
                return choice_idx
        return -1
    
    def possible_pos(self, moves):
        possible_pos_list = []
        for possible_move in moves['move']:
            start_pos = [possible_move[0][0], possible_move[0][1]]
            end_pos = [possible_move[-1][0], possible_move[-1][1]]
            possible_pos_list.append([start_pos, end_pos])
        return possible_pos_list
    
    def listFromTree(self, tree):
        tag_paths = []
        remove_paths = []
        count_list = []
        for i in tree.paths_to_leaves():
            path = []
            r = []
            for j in i:
                path.append(tree.get_node(j).data.position)
                r.append(tree.get_node(j).data.removed)

            tag_paths.append(path)
            remove_paths.append(r)
            count_list.append(self.countRemoves(r))
        
        return {
            'move' : tag_paths,
            'remove' : remove_paths,
            'count' : count_list
        }

    def setFromTree(self, tree):
        tag_paths = []
        remove_paths = []
        for i in tree.paths_to_leaves():
            path = []
            r = []
            for j in i:
                path.append(tree.get_node(j).data.tag)
                r.append(tree.get_node(j).data.remove_tag)

            tag_paths.append(path)
            remove_paths.append(r)
        
        move_set = set(map(tuple, tag_paths))
        remove_set = set(map(tuple, remove_paths))

        return {
            'move' : move_set,
            'remove' : remove_set
        }

    def countRemoves(self, remove_list):
        count = 0
        for i in remove_list:
            if i is not None:
                count = count + 1
        return count

# if __name__=="__main__":

#     win_count = {"Student": 0, "TA": 0}

#     for game in range(1):
#         user_board = Board()
#         move_checker = Student_Move_Checker("White")
#         student_player = StudentAgent.Student_Agent("White")
#         ta_player = TaAgent.Ta_Agent("Black")
        
#         game_playing = True

#         while game_playing:
#             user_board.increment_turn()
        

#             moves = move_checker.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(student_player.side, moves['move']):
#                 win_count["TA"] += 1
#                 break
#             start_time = time.time()
#             choice_idx = student_player.nextMove(deepcopy(user_board))
#             assert (time.time() - start_time) < 1.01
         

            
#             user_board.board = student_player.performMove(moves['move'][choice_idx], moves['remove'][choice_idx], deepcopy(user_board))
#             print("===========================================")
#             print("Student move:")
#             user_board.visualize_board()
#             print("===========================================")  
#             ta_moves = ta_player.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(ta_player.side, ta_moves['move']):
#                 win_count["Student"] += 1
#                 break
#             ta_choice_idx = ta_player.nextMove(ta_moves)
#             user_board.board = ta_player.performMove(ta_moves['move'][ta_choice_idx], ta_moves['remove'][ta_choice_idx], deepcopy(user_board))
#             print("===========================================")
#             print("TA move:")
#             user_board.visualize_board()
#             print("===========================================")
#             if user_board.n_turns >= 500:
#                 win_count["Student"] += 1
#                 game_playing = False

#     for game in range(1):
#         user_board = Board()
#         move_checker = Student_Move_Checker("Black")
#         student_player = StudentAgent.Student_Agent("Black")
#         ta_player = TaAgent.Ta_Agent("White")
        
#         game_playing = True

#         while game_playing:
#             user_board.increment_turn()

#             ta_moves = ta_player.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(ta_player.side, ta_moves['move']):
#                 win_count["Student"] += 1
#                 break
#             ta_choice_idx = ta_player.nextMove(ta_moves)
#             user_board.board = ta_player.performMove(ta_moves['move'][ta_choice_idx], ta_moves['remove'][ta_choice_idx], deepcopy(user_board))
            
#             moves = move_checker.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(student_player.side, moves['move']):
#                 win_count["TA"] += 1
#                 break
#             start_time = time.time()
#             choice_idx = student_player.nextMove(deepcopy(user_board))
#             assert (time.time() - start_time) < 1.01
            
#             user_board.board = student_player.performMove(moves['move'][choice_idx], moves['remove'][choice_idx], deepcopy(user_board))

#             if user_board.n_turns >= 500:
#                 win_count["Student"] += 1
#                 game_playing = False
    
#     print(win_count)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda:0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
if __name__=="__main__":

    win_count = {"Student": 0, "TA": 0}
    
    board = Board()
    move_checker = Student_Move_Checker("White")
    student_player = StudentAgent.Student_Agent("White")
    ta_player = TaAgent.Ta_Agent("Black")
    model = StudentAgent.NN()
    root = StudentAgent.MCTS(board, move_checker, student_player, model, 100)
    theRoot = root.run("White")
        
#         game_playing = True

#         while game_playing:
#             user_board.increment_turn()
        

#             moves = move_checker.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(student_player.side, moves['move']):
#                 win_count["TA"] += 1
#                 break
#             start_time = time.time()
#             choice_idx = student_player.nextMove(deepcopy(user_board))
#             assert (time.time() - start_time) < 1.01
         

            
#             user_board.board = student_player.performMove(moves['move'][choice_idx], moves['remove'][choice_idx], deepcopy(user_board))
#             print("===========================================")
#             print("Student move:")
#             user_board.visualize_board()
#             print("===========================================")  
#             ta_moves = ta_player.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(ta_player.side, ta_moves['move']):
#                 win_count["Student"] += 1
#                 break
#             ta_choice_idx = ta_player.nextMove(ta_moves)
#             user_board.board = ta_player.performMove(ta_moves['move'][ta_choice_idx], ta_moves['remove'][ta_choice_idx], deepcopy(user_board))
#             print("===========================================")
#             print("TA move:")
#             user_board.visualize_board()
#             print("===========================================")
#             if user_board.n_turns >= 500:
#                 win_count["Student"] += 1
#                 game_playing = False

#     for game in range(1):
#         user_board = Board()
#         move_checker = Student_Move_Checker("Black")
#         student_player = StudentAgent.Student_Agent("Black")
#         ta_player = TaAgent.Ta_Agent("White")
        
#         game_playing = True

#         while game_playing:
#             user_board.increment_turn()

#             ta_moves = ta_player.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(ta_player.side, ta_moves['move']):
#                 win_count["Student"] += 1
#                 break
#             ta_choice_idx = ta_player.nextMove(ta_moves)
#             user_board.board = ta_player.performMove(ta_moves['move'][ta_choice_idx], ta_moves['remove'][ta_choice_idx], deepcopy(user_board))
            
#             moves = move_checker.get_all_legal_moves(deepcopy(user_board))
#             if user_board.check_win(student_player.side, moves['move']):
#                 win_count["TA"] += 1
#                 break
#             start_time = time.time()
#             choice_idx = student_player.nextMove(deepcopy(user_board))
#             assert (time.time() - start_time) < 1.01
            
#             user_board.board = student_player.performMove(moves['move'][choice_idx], moves['remove'][choice_idx], deepcopy(user_board))

#             if user_board.n_turns >= 500:
#                 win_count["Student"] += 1
#                 game_playing = False
    
#     print(win_count)
# Out:
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 0 Value: 0, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C6879340> Prior: 0.16 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C6890FA0> Prior: 0.23 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689EAC0> Prior: 0.38 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D580> Prior: 0.29 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C689DD60> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D4F0> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 5 Value: 0.2, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689DB80> Prior: 0.20 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 6 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 7 Value: 0.14285714285714285, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 4 Value: -0.5, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 8 Value: 0.25, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 5 Value: -0.6, <__main__.Board object at 0x000002C7C689DFA0> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689DE50> Prior: 0.17 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 9 Value: 0.3333333333333333, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 6 Value: -0.6666666666666666, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C689DB20> Prior: 0.35 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A21760> Prior: 0.30 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 10 Value: 0.2, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 7 Value: -0.42857142857142855, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D100> Prior: 0.28 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A21130> Prior: 0.29 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 11 Value: 0.09090909090909091, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 8 Value: -0.25, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 4 Value: -0.5, <__main__.Board object at 0x000002C7C689D130> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A21490> Prior: 0.27 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 12 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 9 Value: -0.1111111111111111, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 5 Value: -0.6, <__main__.Board object at 0x000002C7C689DD00> Prior: 0.23 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A216A0> Prior: 0.25 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 13 Value: 0.07692307692307693, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 10 Value: -0.2, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 6 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DD00> Prior: 0.23 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A21CA0> Prior: 0.23 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A219A0> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 14 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 11 Value: -0.09090909090909091, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 7 Value: -0.42857142857142855, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689DB20> Prior: 0.35 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A21DF0> Prior: 0.38 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D5E0> Prior: 0.36 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 15 Value: 0.06666666666666667, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 12 Value: -0.16666666666666666, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 8 Value: -0.25, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D460> Prior: 0.33 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A21A30> Prior: 0.28 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 16 Value: 0.0, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C6890AF0> Prior: 0.28 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A21FD0> Prior: 0.27 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 17 Value: -0.058823529411764705, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 13 Value: -0.07692307692307693, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 9 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DD00> Prior: 0.23 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A21CA0> Prior: 0.23 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A21CD0> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D790> Prior: 0.30 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 18 Value: -0.1111111111111111, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 14 Value: 0.0, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 10 Value: -0.4, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C7C689D460> Prior: 0.33 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A21A30> Prior: 0.28 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C7C689D7F0> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 19 Value: -0.05263157894736842, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 15 Value: -0.06666666666666667, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 11 Value: -0.2727272727272727, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 5 Value: -0.2, <__main__.Board object at 0x000002C7C689D820> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689DFD0> Prior: 0.28 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 20 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 16 Value: -0.125, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 12 Value: -0.16666666666666666, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 6 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0A0> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689D160> Prior: 0.28 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 21 Value: -0.047619047619047616, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 17 Value: -0.058823529411764705, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 13 Value: -0.23076923076923078, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 7 Value: -0.14285714285714285, <__main__.Board object at 0x000002C7C689D0A0> Prior: 0.32 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C689D160> Prior: 0.28 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A1E9A0> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 22 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 18 Value: -0.1111111111111111, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 14 Value: -0.14285714285714285, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 8 Value: -0.25, <__main__.Board object at 0x000002C7C689D730> Prior: 0.30 Count: 0 Value: 0, <__main__.Board object at 0x000002C7C689DA30> Prior: 0.27 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 23 Value: 0.043478260869565216, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 19 Value: -0.15789473684210525, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 15 Value: -0.06666666666666667, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 9 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DB20> Prior: 0.35 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A21DF0> Prior: 0.38 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C7C689D340> Prior: 0.35 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E370> Prior: 0.33 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 24 Value: 0.08333333333333333, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 20 Value: -0.2, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 16 Value: 0.0, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 10 Value: -0.4, <__main__.Board object at 0x000002C7C689D460> Prior: 0.33 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A21A30> Prior: 0.28 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A210A0> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1EBE0> Prior: 0.39 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 25 Value: 0.12, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 21 Value: -0.23809523809523808, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 17 Value: 0.058823529411764705, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 11 Value: -0.45454545454545453, <__main__.Board object at 0x000002C7C689D0A0> Prior: 0.32 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689D160> Prior: 0.28 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689D4C0> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E940> Prior: 0.20 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 26 Value: 0.15384615384615385, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 22 Value: -0.2727272727272727, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 18 Value: 0.1111111111111111, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 12 Value: -0.5, <__main__.Board object at 0x000002C7C689DB20> Prior: 0.35 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A21DF0> Prior: 0.38 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C7C689D9A0> Prior: 0.34 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E250> Prior: 0.37 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 27 Value: 0.18518518518518517, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 23 Value: -0.30434782608695654, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 19 Value: 0.15789473684210525, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 13 Value: -0.5384615384615384, <__main__.Board object at 0x000002C7C689D460> Prior: 0.33 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A21A30> Prior: 0.28 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D070> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E5E0> Prior: 0.36 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 28 Value: 0.21428571428571427, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 24 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 20 Value: 0.2, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 14 Value: -0.5714285714285714, <__main__.Board object at 0x000002C7C689D0A0> Prior: 0.32 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C7C689D160> Prior: 0.28 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DEB0> Prior: 0.23 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E7C0> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 29 Value: 0.2413793103448276, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 25 Value: -0.36, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 21 Value: 0.23809523809523808, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 15 Value: -0.6, <__main__.Board object at 0x000002C7C689DB20> Prior: 0.35 Count: 4 Value: 0.5, <__main__.Board object at 0x000002C781A21DF0> Prior: 0.38 Count: 3 Value: -1.0, <__main__.Board object at 0x000002C7C689D5E0> Prior: 0.36 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A1EF70> Prior: 0.38 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 30 Value: 0.26666666666666666, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 26 Value: -0.38461538461538464, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 22 Value: 0.2727272727272727, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 16 Value: -0.625, <__main__.Board object at 0x000002C7C689D460> Prior: 0.33 Count: 4 Value: 0.5, <__main__.Board object at 0x000002C781A21A30> Prior: 0.28 Count: 4 Value: -0.5, <__main__.Board object at 0x000002C7C689D7F0> Prior: 0.26 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A1E310> Prior: 0.38 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 31 Value: 0.2903225806451613, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 27 Value: -0.4074074074074074, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 23 Value: 0.30434782608695654, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 17 Value: -0.6470588235294118, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A1E820> Prior: 0.40 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 32 Value: 0.25, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 28 Value: -0.35714285714285715, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 24 Value: 0.25, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 18 Value: -0.5555555555555556, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A1E760> Prior: 0.37 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31FA0> Prior: 0.33 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 33 Value: 0.2727272727272727, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 29 Value: -0.3793103448275862, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 25 Value: 0.28, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 19 Value: -0.5789473684210527, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A1E760> Prior: 0.37 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A31520> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A314F0> Prior: 0.28 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 34 Value: 0.23529411764705882, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 30 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 26 Value: 0.23076923076923078, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 20 Value: -0.5, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A1EA00> Prior: 0.36 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31EB0> Prior: 0.33 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 35 Value: 0.2571428571428571, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 31 Value: -0.3548387096774194, <__main__.Board object at 0x000002C7C689D580> Prior: 0.29 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A31250> Prior: 0.37 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 36 Value: 0.2777777777777778, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 32 Value: -0.375, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 27 Value: 0.25925925925925924, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 21 Value: -0.5238095238095238, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 5 Value: 0.2, <__main__.Board object at 0x000002C781A1EA00> Prior: 0.36 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A314C0> Prior: 0.33 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31760> Prior: 0.32 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 37 Value: 0.2972972972972973, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 33 Value: -0.3939393939393939, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 28 Value: 0.2857142857142857, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 22 Value: -0.5454545454545454, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 6 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A1EA00> Prior: 0.36 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A31EB0> Prior: 0.33 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A31C10> Prior: 0.39 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 38 Value: 0.2631578947368421, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 34 Value: -0.35294117647058826, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 29 Value: 0.2413793103448276, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 23 Value: -0.4782608695652174, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 7 Value: 0.14285714285714285, <__main__.Board object at 0x000002C781A1E9D0> Prior: 0.35 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31220> Prior: 0.33 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 39 Value: 0.28205128205128205, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 35 Value: -0.37142857142857144, <__main__.Board object at 0x000002C7C689D760> Prior: 0.26 Count: 30 Value: 0.26666666666666666, <__main__.Board object at 0x000002C7C689D850> Prior: 0.33 Count: 24 Value: -0.5, <__main__.Board object at 0x000002C7C689DE80> Prior: 0.38 Count: 8 Value: 0.25, <__main__.Board object at 0x000002C781A1E9D0> Prior: 0.35 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A31C70> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31CD0> Prior: 0.32 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 40 Value: 0.3, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 36 Value: -0.3888888888888889, <__main__.Board object at 0x000002C7C689DD60> Prior: 0.26 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C7C689D4F0> Prior: 0.22 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A1EA60> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 41 Value: 0.3170731707317073, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 37 Value: -0.40540540540540543, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 42 Value: 0.2857142857142857, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 38 Value: -0.3684210526315789, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689DBB0> Prior: 0.34 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31E20> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 43 Value: 0.2558139534883721, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 39 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689DAF0> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A315E0> Prior: 0.27 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 44 Value: 0.22727272727272727, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 40 Value: -0.3, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 4 Value: -0.5, <__main__.Board object at 0x000002C7C689D670> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1EB80> Prior: 0.27 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 45 Value: 0.2, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 41 Value: -0.2682926829268293, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 5 Value: -0.6, <__main__.Board object at 0x000002C7C689DC10> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E0A0> Prior: 0.25 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 46 Value: 0.17391304347826086, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 42 Value: -0.23809523809523808, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 6 Value: -0.6666666666666666, <__main__.Board object at 0x000002C7C689DBE0> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A1E520> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 47 Value: 0.14893617021276595, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 43 Value: -0.20930232558139536, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 7 Value: -0.7142857142857143, <__main__.Board object at 0x000002C7C689D7C0> Prior: 0.23 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A31D00> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 48 Value: 0.125, <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C7C689EAC0> Prior: 0.38 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A398B0> Prior: 0.37 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 49 Value: 0.14285714285714285, <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C7C689E8E0> Prior: 0.36 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A39910> Prior: 0.25 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 50 Value: 0.12, <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C7C689E8E0> Prior: 0.36 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A395B0> Prior: 0.36 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A39400> Prior: 0.34 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 51 Value: 0.09803921568627451, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 44 Value: -0.18181818181818182, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 8 Value: -0.75, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A39880> Prior: 0.36 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 52 Value: 0.11538461538461539, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 45 Value: -0.2, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 9 Value: -0.5555555555555556, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A39880> Prior: 0.36 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A39E20> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 53 Value: 0.09433962264150944, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 46 Value: -0.17391304347826086, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 10 Value: -0.6, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A397C0> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A39F70> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 54 Value: 0.07407407407407407, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 47 Value: -0.14893617021276595, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 11 Value: -0.6363636363636364, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 5 Value: 0.2, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 4 Value: -0.5, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A39F40> Prior: 0.23 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 55 Value: 0.09090909090909091, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 48 Value: -0.16666666666666666, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 12 Value: -0.5, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 6 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 5 Value: -0.2, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A39790> Prior: 0.22 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A39D90> Prior: 0.21 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 56 Value: 0.10714285714285714, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 49 Value: -0.1836734693877551, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 13 Value: -0.38461538461538464, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 7 Value: -0.14285714285714285, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 6 Value: 0.0, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A39F10> Prior: 0.22 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A489D0> Prior: 0.21 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 57 Value: 0.08771929824561403, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 50 Value: -0.16, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 14 Value: -0.42857142857142855, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 8 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 7 Value: -0.14285714285714285, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A398E0> Prior: 0.20 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 58 Value: 0.10344827586206896, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 51 Value: -0.17647058823529413, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 15 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 9 Value: -0.1111111111111111, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 8 Value: 0.0, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A399D0> Prior: 0.20 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48BB0> Prior: 0.16 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 59 Value: 0.0847457627118644, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 52 Value: -0.15384615384615385, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 16 Value: -0.375, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 10 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 9 Value: -0.1111111111111111, <__main__.Board object at 0x000002C781A39220> Prior: 0.20 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48E80> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 60 Value: 0.1, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 53 Value: -0.16981132075471697, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 17 Value: -0.29411764705882354, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 11 Value: -0.09090909090909091, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 10 Value: 0.0, <__main__.Board object at 0x000002C781A39220> Prior: 0.20 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48E80> Prior: 0.19 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48340> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 61 Value: 0.08196721311475409, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 54 Value: -0.14814814814814814, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 18 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 12 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 11 Value: -0.09090909090909091, <__main__.Board object at 0x000002C781A39670> Prior: 0.18 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A488E0> Prior: 0.16 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 62 Value: 0.0967741935483871, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 55 Value: -0.16363636363636364, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 19 Value: -0.2631578947368421, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 13 Value: -0.07692307692307693, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 12 Value: 0.0, <__main__.Board object at 0x000002C781A39670> Prior: 0.18 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48490> Prior: 0.16 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A487F0> Prior: 0.17 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 63 Value: 0.1111111111111111, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 56 Value: -0.17857142857142858, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 20 Value: -0.2, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 14 Value: -0.14285714285714285, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 13 Value: 0.07692307692307693, <__main__.Board object at 0x000002C781A39670> Prior: 0.18 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A48E50> Prior: 0.15 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48F70> Prior: 0.15 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 64 Value: 0.09375, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 57 Value: -0.15789473684210525, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 21 Value: -0.23809523809523808, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 15 Value: -0.06666666666666667, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 14 Value: 0.0, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A39F10> Prior: 0.22 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A39340> Prior: 0.32 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48430> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 65 Value: 0.07692307692307693, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 58 Value: -0.13793103448275862, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 22 Value: -0.2727272727272727, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 16 Value: 0.0, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 15 Value: -0.06666666666666667, <__main__.Board object at 0x000002C781A39670> Prior: 0.18 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A48E50> Prior: 0.15 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48F70> Prior: 0.15 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48940> Prior: 0.14 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 66 Value: 0.06060606060606061, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 59 Value: -0.11864406779661017, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 23 Value: -0.30434782608695654, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 17 Value: 0.058823529411764705, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 16 Value: -0.125, <__main__.Board object at 0x000002C781A39B50> Prior: 0.13 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48D30> Prior: 0.11 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 67 Value: 0.04477611940298507, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 60 Value: -0.1, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 24 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 18 Value: 0.1111111111111111, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 17 Value: -0.17647058823529413, <__main__.Board object at 0x000002C781A39880> Prior: 0.36 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A39E20> Prior: 0.24 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A488B0> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 68 Value: 0.029411764705882353, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 61 Value: -0.08196721311475409, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 25 Value: -0.36, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 19 Value: 0.15789473684210525, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 18 Value: -0.2222222222222222, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A399D0> Prior: 0.20 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48BB0> Prior: 0.16 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48A00> Prior: 0.14 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 69 Value: 0.043478260869565216, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 62 Value: -0.0967741935483871, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 26 Value: -0.3076923076923077, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 20 Value: 0.1, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 19 Value: -0.15789473684210525, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A48880> Prior: 0.19 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48280> Prior: 0.13 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 70 Value: 0.02857142857142857, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 63 Value: -0.07936507936507936, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 27 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 21 Value: 0.14285714285714285, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 20 Value: -0.2, <__main__.Board object at 0x000002C781A39220> Prior: 0.20 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48E80> Prior: 0.19 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48340> Prior: 0.19 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48790> Prior: 0.20 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 71 Value: 0.04225352112676056, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 64 Value: -0.09375, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 28 Value: -0.2857142857142857, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 22 Value: 0.09090909090909091, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 21 Value: -0.14285714285714285, <__main__.Board object at 0x000002C781A39220> Prior: 0.20 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A48E80> Prior: 0.19 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A48340> Prior: 0.19 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48790> Prior: 0.20 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48760> Prior: 0.26 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 72 Value: 0.027777777777777776, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 65 Value: -0.07692307692307693, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 29 Value: -0.3103448275862069, <__main__.Board object at 0x000002C7C689DBB0> Prior: 0.34 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A31E20> Prior: 0.26 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48A60> Prior: 0.28 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 73 Value: 0.0136986301369863, <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 4 Value: 0.5, <__main__.Board object at 0x000002C7C689E8E0> Prior: 0.36 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A393D0> Prior: 0.34 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48640> Prior: 0.31 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 74 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 66 Value: -0.06060606060606061, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 30 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 23 Value: 0.13043478260869565, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 22 Value: -0.18181818181818182, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A39F10> Prior: 0.22 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A39CD0> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4A2B0> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 75 Value: -0.013333333333333334, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 67 Value: -0.04477611940298507, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 31 Value: -0.3548387096774194, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 24 Value: 0.16666666666666666, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 23 Value: -0.21739130434782608, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A48880> Prior: 0.19 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48280> Prior: 0.13 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A48D60> Prior: 0.11 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 76 Value: 0.0, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 68 Value: -0.058823529411764705, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 32 Value: -0.3125, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 25 Value: 0.12, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 24 Value: -0.16666666666666666, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 5 Value: -0.2, <__main__.Board object at 0x000002C781A399D0> Prior: 0.20 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48BB0> Prior: 0.16 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48100> Prior: 0.14 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A48B20> Prior: 0.12 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 77 Value: -0.012987012987012988, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 69 Value: -0.043478260869565216, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 33 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 26 Value: 0.15384615384615385, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 25 Value: -0.2, <__main__.Board object at 0x000002C781A39220> Prior: 0.20 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A48E80> Prior: 0.19 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A48340> Prior: 0.19 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A48790> Prior: 0.20 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48670> Prior: 0.21 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4A700> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 78 Value: -0.02564102564102564, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 70 Value: -0.02857142857142857, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 34 Value: -0.35294117647058826, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 27 Value: 0.18518518518518517, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 26 Value: -0.23076923076923078, <__main__.Board object at 0x000002C781A39670> Prior: 0.18 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A48E50> Prior: 0.15 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A48F70> Prior: 0.15 Count: 2 Value: 1.0, <__main__.Board object at 0x000002C781A48940> Prior: 0.14 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4AA60> Prior: 0.17 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 79 Value: -0.0379746835443038, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 71 Value: -0.014084507042253521, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 35 Value: -0.37142857142857144, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 28 Value: 0.21428571428571427, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 27 Value: -0.25925925925925924, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 6 Value: 0.0, <__main__.Board object at 0x000002C781A399D0> Prior: 0.20 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A48BB0> Prior: 0.16 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A48100> Prior: 0.14 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A48B20> Prior: 0.12 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A4AD90> Prior: 0.14 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 80 Value: -0.025, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 72 Value: -0.027777777777777776, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 36 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 29 Value: 0.1724137931034483, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 28 Value: -0.21428571428571427, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 7 Value: -0.14285714285714285, <__main__.Board object at 0x000002C781A48880> Prior: 0.19 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48280> Prior: 0.13 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A48D60> Prior: 0.11 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A4A040> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 81 Value: -0.037037037037037035, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 73 Value: -0.0136986301369863, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 37 Value: -0.35135135135135137, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 30 Value: 0.2, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 29 Value: -0.2413793103448276, <__main__.Board object at 0x000002C781A39880> Prior: 0.36 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A39E20> Prior: 0.24 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A48F40> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4AAC0> Prior: 0.23 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 82 Value: -0.04878048780487805, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 74 Value: 0.0, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 38 Value: -0.3684210526315789, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 31 Value: 0.22580645161290322, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 30 Value: -0.26666666666666666, <__main__.Board object at 0x000002C781A39460> Prior: 0.22 Count: 8 Value: 0.0, <__main__.Board object at 0x000002C781A48880> Prior: 0.19 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A48280> Prior: 0.13 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C781A48D60> Prior: 0.11 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A4A040> Prior: 0.19 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A4A640> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 83 Value: -0.060240963855421686, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 75 Value: 0.013333333333333334, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 39 Value: -0.38461538461538464, <__main__.Board object at 0x000002C7C689DAF0> Prior: 0.26 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A315E0> Prior: 0.27 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4A1C0> Prior: 0.35 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 84 Value: -0.07142857142857142, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 76 Value: 0.02631578947368421, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 40 Value: -0.4, <__main__.Board object at 0x000002C7C689D670> Prior: 0.26 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A1EB80> Prior: 0.27 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4A3D0> Prior: 0.33 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 85 Value: -0.08235294117647059, <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 77 Value: 0.03896103896103896, <__main__.Board object at 0x000002C7C689DC70> Prior: 0.26 Count: 41 Value: -0.4146341463414634, <__main__.Board object at 0x000002C7C689D0D0> Prior: 0.18 Count: 32 Value: 0.25, <__main__.Board object at 0x000002C781A311C0> Prior: 0.24 Count: 31 Value: -0.2903225806451613, <__main__.Board object at 0x000002C781A39C10> Prior: 0.24 Count: 5 Value: 0.2, <__main__.Board object at 0x000002C781A39F10> Prior: 0.22 Count: 3 Value: -1.0, <__main__.Board object at 0x000002C781A39100> Prior: 0.24 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4AA00> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 86 Value: -0.09302325581395349, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 3 Value: 0.3333333333333333, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C7C6890AF0> Prior: 0.28 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A21FD0> Prior: 0.27 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4AFA0> Prior: 0.32 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 87 Value: -0.08045977011494253, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C7C6890AF0> Prior: 0.28 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A21D30> Prior: 0.27 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4AD00> Prior: 0.18 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 88 Value: -0.06818181818181818, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 5 Value: -0.2, <__main__.Board object at 0x000002C7C6879880> Prior: 0.13 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4A550> Prior: 0.22 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 89 Value: -0.07865168539325842, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 6 Value: 0.0, <__main__.Board object at 0x000002C7C6879880> Prior: 0.13 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4A520> Prior: 0.27 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4A2E0> Prior: 0.31 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 90 Value: -0.08888888888888889, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 7 Value: 0.14285714285714285, <__main__.Board object at 0x000002C7C6879880> Prior: 0.13 Count: 2 Value: -1.0, <__main__.Board object at 0x000002C781A4A520> Prior: 0.27 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A4A2E0> Prior: 0.31 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4AA30> Prior: 0.35 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 91 Value: -0.07692307692307693, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 8 Value: 0.0, <__main__.Board object at 0x000002C7C6879880> Prior: 0.13 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A4A520> Prior: 0.27 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A4A070> Prior: 0.29 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A4A1F0> Prior: 0.29 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 92 Value: -0.06521739130434782, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 9 Value: -0.1111111111111111, <__main__.Board object at 0x000002C7C6879820> Prior: 0.11 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A58F40> Prior: 0.21 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 93 Value: -0.07526881720430108, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 10 Value: 0.0, <__main__.Board object at 0x000002C7C6879820> Prior: 0.11 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4AD60> Prior: 0.26 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A58B20> Prior: 0.19 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 94 Value: -0.06382978723404255, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 11 Value: -0.09090909090909091, <__main__.Board object at 0x000002C7C68798B0> Prior: 0.10 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A582E0> Prior: 0.20 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 95 Value: -0.07368421052631578, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 12 Value: 0.0, <__main__.Board object at 0x000002C7C68798B0> Prior: 0.10 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A4A9D0> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A58100> Prior: 0.24 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 96 Value: -0.0625, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 13 Value: -0.07692307692307693, <__main__.Board object at 0x000002C7C6879820> Prior: 0.11 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A4AD60> Prior: 0.26 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A58B20> Prior: 0.19 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A58070> Prior: 0.23 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 97 Value: -0.05154639175257732, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 14 Value: -0.14285714285714285, <__main__.Board object at 0x000002C7C68798B0> Prior: 0.10 Count: 2 Value: 0.0, <__main__.Board object at 0x000002C781A4A9D0> Prior: 0.25 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A58100> Prior: 0.24 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A586D0> Prior: 0.29 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 98 Value: -0.04081632653061224, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 15 Value: -0.2, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C7C6890AF0> Prior: 0.28 Count: 3 Value: -0.3333333333333333, <__main__.Board object at 0x000002C781A21EB0> Prior: 0.25 Count: 0 Value: 0, <__main__.Board object at 0x000002C781A58BE0> Prior: 0.30 Count: 0 Value: 0]
# [<__main__.Board object at 0x000002C7C6816D30> Prior: 0.00 Count: 99 Value: -0.050505050505050504, <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 16 Value: -0.125, <__main__.Board object at 0x000002C7C68795B0> Prior: 0.14 Count: 5 Value: -0.2, <__main__.Board object at 0x000002C7C6890AF0> Prior: 0.28 Count: 4 Value: 0.0, <__main__.Board object at 0x000002C781A21EB0> Prior: 0.25 Count: 1 Value: -1.0, <__main__.Board object at 0x000002C781A58BE0> Prior: 0.30 Count: 1 Value: 1.0, <__main__.Board object at 0x000002C781A58490> Prior: 0.27 Count: 0 Value: 0]

# %%
print(theRoot.children)
# Out:
# {((5, 0), (4, 0)): <__main__.Board object at 0x000002C7B9C03C10> Prior: 0.14 Count: 17 Value: -0.058823529411764705, ((5, 1), (4, 1)): <__main__.Board object at 0x000002C7B9C03FA0> Prior: 0.27 Count: 78 Value: 0.05128205128205128, ((5, 6), (4, 6)): <__main__.Board object at 0x000002C7C68791F0> Prior: 0.36 Count: 5 Value: 0.6}
